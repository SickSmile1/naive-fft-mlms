# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
arr = np.fromfile("240_grid", sep='\t')
arr2 = arr.reshape(240,240)

surf = plt.imshow(arr2,cmap='viridis')
plt.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
x,y = np.loadtxt("timings_home.txt",
                 delimiter='\t',usecols=(0, 1), unpack=True)
fig, ax = plt.subplots()
print(x)
x2 = np.power(x,2)

#ax.set_yscale("log")
#ax.set_xscale('log')
plt.xlabel("number of nodes")
plt.ylabel("time in seconds")
plt.grid(color='r', alpha=0.2, linestyle='-', linewidth=.5)
ax.plot(x2,y)

#ax.set_aspect("equal")
# Out:
# [ 40.  60.  80. 100. 120. 140. 160. 180. 200. 220. 240. 260. 280. 300.
#  320. 340.]

# %%
arr = np.fromfile("cC1", sep='\t')
arr2 = arr.reshape(17,17)

surf = plt.imshow(arr2,cmap='viridis')
plt.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
