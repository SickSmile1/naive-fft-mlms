# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
arr = np.fromfile("120_grid", sep='\t')
arr2 = arr.reshape(120,120)

surf = plt.imshow(arr2,cmap='viridis')
plt.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
x,y = np.loadtxt("timings_home.txt",
                 delimiter='\t',usecols=(0, 1), unpack=True)
fig, ax = plt.subplots()
print(x)
x2 = np.power(x,2)
print(y)
ax.set_yscale("log")
ax.set_xscale('log')
plt.xlabel("number of nodes")
plt.ylabel("time in seconds")
plt.grid(color='r', alpha=0.2, linestyle='-', linewidth=.5)
ax.plot(x2,y)
# Out:
# [ 40.  60.  80. 100. 120. 140. 160. 180. 200. 220. 240. 260. 280. 300.
#  320. 340.]
# [6.07589e-03 1.06350e-01 5.54394e-01 1.75816e+00 4.36023e+00 9.15156e+00
#  1.65102e+01 2.81655e+01 4.50884e+01 6.86828e+01 1.02537e+02 1.45401e+02
#  2.03500e+02 2.68976e+02 3.57683e+02 4.72160e+02]
